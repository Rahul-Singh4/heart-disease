# %%
#import lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import data
heart_disease=pd.read_csv("data/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Count total no of cases of heart disease either positive or negative
heart_disease["target"].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
fig,ax= plt.subplots(figsize=(3,5))
heart_disease["target"].plot(kind="hist",
             );
ax.set(title="Heart Disease Vs Not Heart Disease",
      xlabel="Target",
      ylabel="Patient counts");

# %%
heart_disease.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart_disease.nunique(axis=0)
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
heart_disease.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
import seaborn as sns
subData = heart_disease[['age','trestbps','chol','thalach','oldpeak']]
sns.pairplot(subData)

# %%
pos_data = heart_disease[heart_disease['target']==0]
pos_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean    56.601449    0.826087    0.478261  134.398551  251.086957    0.159420
# std      7.962082    0.380416    0.905920   18.729944   49.454614    0.367401
# min     35.000000    0.000000    0.000000  100.000000  131.000000    0.000000
# 25%     52.000000    1.000000    0.000000  120.000000  217.250000    0.000000
# 50%     58.000000    1.000000    0.000000  130.000000  249.000000    0.000000
# 75%     62.000000    1.000000    0.000000  144.750000  283.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  409.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean     0.449275  139.101449    0.550725    1.585507    1.166667    1.166667
# ...

# %%
plt.style.use('seaborn-whitegrid')
#subplot of chol,age and thalach
fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                          sharex=True)
sc1=ax0.scatter(x=heart_disease["age"],
               y=heart_disease["thalach"],
               c=heart_disease["target"],
               cmap='winter')
ax0.set_xlim([10,80]);
ax1.axhline(heart_disease["chol"].mean(),linestyle="--")
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");
ax0.set_ylim([60,220])
sc2=ax1.scatter(x=heart_disease["age"],
               y=heart_disease["chol"],
               c=heart_disease["target"],
               cmap='winter')
ax0.set(title="Heart Disease and Max Heart Rate",
       ylabel="Max Heart Rate")
ax0.legend(*sc1.legend_elements(),title="Target")
ax0.axhline(heart_disease["thalach"].mean(),linestyle="--")
ax1.set(title="Heart Disease and Cholorestrol",
       xlabel="Age",
       ylabel="Cholorosterol")
ax1.legend(*sc2.legend_elements(),title="Target")

# %%
# calculate correlation matrix

corr = heart_disease.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
sns.heatmap(corr, xticklabels=corr.columns,
            yticklabels=corr.columns, 
            annot=True,
            cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
# Filtering positive results of heart disease
pos_data = heart_disease[heart_disease['target']==1]
pos_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean    52.496970    0.563636    1.375758  129.303030  242.230303    0.139394
# std      9.550651    0.497444    0.952222   16.169613   53.552872    0.347412
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     44.000000    0.000000    1.000000  120.000000  208.000000    0.000000
# 50%     52.000000    1.000000    2.000000  130.000000  234.000000    0.000000
# 75%     59.000000    1.000000    2.000000  140.000000  267.000000    0.000000
# max     76.000000    1.000000    3.000000  180.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     0.593939  158.466667    0.139394    0.583030    1.593939    0.363636
# ...

# %%
len(pos_data)
# Out:
# 165

# %%
# Filtering negative results of heart disease
neg_data = heart_disease[heart_disease['target']==0]
neg_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean    56.601449    0.826087    0.478261  134.398551  251.086957    0.159420
# std      7.962082    0.380416    0.905920   18.729944   49.454614    0.367401
# min     35.000000    0.000000    0.000000  100.000000  131.000000    0.000000
# 25%     52.000000    1.000000    0.000000  120.000000  217.250000    0.000000
# 50%     58.000000    1.000000    0.000000  130.000000  249.000000    0.000000
# 75%     62.000000    1.000000    0.000000  144.750000  283.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  409.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean     0.449275  139.101449    0.550725    1.585507    1.166667    1.166667
# ...

# %%
len(neg_data)
# Out:
# 138

# %%
# Split the data info features and label (usually X and y)
# Create X features matrix
X=heart_disease.drop("target",axis=1)
# Create y labels
y=heart_disease["target"]

# %%
# split data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ## Choose an algorithm

# %% [markdown]
# Model 1: Logistic Regression

# %%
from sklearn.metrics import classification_report 
from sklearn.linear_model import LogisticRegression

model1 = LogisticRegression(max_iter=1000) # get instance of model
model1.fit(X_train, y_train) # Train/Fit model 

y_pred1 = model1.predict(X_test) # get y predictions
print(classification_report(y_test, y_pred1)) # output accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.78        23
#            1       0.89      0.82      0.85        38
#
#     accuracy                           0.82        61
#    macro avg       0.81      0.82      0.81        61
# weighted avg       0.83      0.82      0.82        61

# %% [markdown]
# Model 2: K-NN(K-Nearest Neighbor)

# %%
from sklearn.neighbors import KNeighborsClassifier

model2 = KNeighborsClassifier() # get instance of model
model2.fit(X_train, y_train) # Train/Fit model 

y_pred2 = model2.predict(X_test) # get y predictions
print(classification_report(y_test, y_pred2)) # output accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.74      0.64        23
#            1       0.81      0.66      0.72        38
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.70      0.68        61
# weighted avg       0.72      0.69      0.69        61

# %% [markdown]
# Model 3: SVM (Support Vector Machine)

# %%
from sklearn.metrics import classification_report 
from sklearn.svm import SVC

model3 = SVC(random_state=1) # get instance of model
model3.fit(X_train, y_train) # Train/Fit model 

y_pred3 = model3.predict(X_test) # get y predictions
print(classification_report(y_test, y_pred3)) # output accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.61      0.57        23
#            1       0.74      0.68      0.71        38
#
#     accuracy                           0.66        61
#    macro avg       0.64      0.65      0.64        61
# weighted avg       0.67      0.66      0.66        61

# %% [markdown]
# Model 4: Naives Bayes Classifier

# %%
from sklearn.metrics import classification_report 
from sklearn.naive_bayes import GaussianNB

model4 = GaussianNB() # get instance of model
model4.fit(X_train, y_train) # Train/Fit model 

y_pred4 = model4.predict(X_test) # get y predictions
print(classification_report(y_test, y_pred4)) # output accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.83      0.75        23
#            1       0.88      0.76      0.82        38
#
#     accuracy                           0.79        61
#    macro avg       0.78      0.79      0.78        61
# weighted avg       0.80      0.79      0.79        61

# %% [markdown]
# Model 5: Random Forest Classifier

# %%
from sklearn.metrics import classification_report 
from sklearn.ensemble import RandomForestClassifier

model5 = RandomForestClassifier(random_state=1)# get instance of model
model5.fit(X_train, y_train) # Train/Fit model 

y_pred5 = model5.predict(X_test) # get y predictions
print(classification_report(y_test, y_pred5)) # output accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.83      0.76        23
#            1       0.88      0.79      0.83        38
#
#     accuracy                           0.80        61
#    macro avg       0.79      0.81      0.80        61
# weighted avg       0.81      0.80      0.81        61

# %%
# Confusion matrix 
from sklearn.metrics import confusion_matrix
y_preds=model6.predict(X_test)
confusion_matrix(y_test,y_pred6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a429d29c57b> in <module>
#       1 # Confusion matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 y_preds=model6.predict(X_test)
#       4 confusion_matrix(y_test,y_pred6)
#
# NameError: name 'model6' is not defined

# %%
pd.crosstab(y_test,y_pred6,rownames=["Actual label"],colnames=["Predicted lables"])

# %%
import seaborn as sns
sns.set(font_scale=1.5)
conf_mat=confusion_matrix(y_test,y_preds)
sns.heatmap(conf_mat);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-76706a639894> in <module>
#       1 import seaborn as sns
#       2 sns.set(font_scale=1.5)
# ----> 3 conf_mat=confusion_matrix(y_test,y_preds)
#       4 sns.heatmap(conf_mat);
#
# NameError: name 'y_preds' is not defined

# %%
def plot_conf_mat(conf_mat):
    fig,ax=plt.subplots(figsize=(3,3))
    ax=sns.heatmap(conf_mat,annot=True,cbar=False)
    plt.xlabel("True label")
    plt.ylabel("False label")
    bottom,top=ax.get_ylim()
    ax.set_ylim(bottom+0.5,top-0.5);
plot_conf_mat(conf_mat)

# %%
from sklearn.metrics import classification_report 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
def evaluate_preds(y_true,y_preds):
    """
    Performs evaluation comparsion on y_true labels vs. y_preds labels.
    """
    accuracy = accuracy_score(y_true,y_preds)
    precision = precision_score(y_true,y_preds)
    recall = recall_score(y_true,y_preds)
    f1 = f1_score(y_true,y_preds)
    metric_dict={"accuracy" : round(accuracy,2),
                "precision": round(precision,2),
                "recall ": round(recall,2),
                "f1" : round(f1,2)}
    print(f"Accuracy : {accuracy*100:.2f}%")
    print(f"Precision :{precision:.2f}")
    print(f"Recall :{recall:.2f}")
    print(f"F1_score :{f1:.2f}")
    
    return metric_dict

# %%
log_reg=evaluate_preds(y_test,y_pred1)
log_reg
# Out:
# Accuracy : 81.97%
# Precision :0.89
# Recall :0.82
# F1_score :0.85
# {'accuracy': 0.82, 'precision': 0.89, 'recall ': 0.82, 'f1': 0.85}

# %%
knn_neighbor=evaluate_preds(y_test,y_pred2)
# Out:
# Accuracy : 68.85%
# Precision :0.81
# Recall :0.66
# F1_score :0.72

# %%
svm=evaluate_preds(y_test,y_pred3)
# Out:
# Accuracy : 65.57%
# Precision :0.74
# Recall :0.68
# F1_score :0.71

# %%
naive_bayes=evaluate_preds(y_test,y_pred4)
# Out:
# Accuracy : 78.69%
# Precision :0.88
# Recall :0.76
# F1_score :0.82

# %%
random_forest=evaluate_preds(y_test,y_pred5)
# Out:
# Accuracy : 80.33%
# Precision :0.88
# Recall :0.79
# F1_score :0.83

# %% [markdown]
# Let's compare our different models metrics

# %%
compare_metrics=pd.DataFrame({"Logistic Regression ":log_reg,
                             "Knn_Neighbor":knn_neighbor,
                             "Support Vector Machine ": svm,
                             "Naive Bayes": naive_bayes,
                             "Random Forest":random_forest})
compare_metrics.plot.bar(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(model5.predict(sc.transform([[20,1,2,110,230,1,1,140,1,2.2,2,0,2]])))
# Out:
# [1]
